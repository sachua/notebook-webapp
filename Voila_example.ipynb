# %%
# !pip install --index-url https://pypi.org/simple folium
# Out:
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Requirement already satisfied: folium in /opt/conda/lib/python3.8/site-packages (0.12.1.post1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from folium) (1.19.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.8/site-packages (from folium) (3.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from folium) (2.25.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests->folium) (2.10)
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Collecting voila
#   Downloading voila-0.3.6-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 8.9 MB/s eta 0:00:01
# Collecting websockets>=9.0
#   Downloading websockets-10.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (111 kB)
#      |████████████████████████████████| 111 kB 40.3 MB/s eta 0:00:01
# Requirement already satisfied: traitlets<6,>=5.0.3 in /opt/conda/lib/python3.8/site-packages (from voila) (5.0.5)
# Collecting nbconvert<7,>=6.4.5
#   Downloading nbconvert-6.5.3-py3-none-any.whl (563 kB)
#      |████████████████████████████████| 563 kB 62.2 MB/s eta 0:00:01
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /opt/conda/lib/python3.8/site-packages (from voila) (2.4.0)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from voila) (0.5.3)
# Requirement already satisfied: jupyter-client<8,>=6.1.3 in /opt/conda/lib/python3.8/site-packages (from voila) (6.1.12)
# Collecting jupyter-core>=4.11.0
#   Downloading jupyter_core-4.11.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 11.2 MB/s eta 0:00:01
# Collecting jupyter-server<2.0.0,>=1.18
#   Downloading jupyter_server-1.18.1-py3-none-any.whl (344 kB)
#      |████████████████████████████████| 344 kB 21.5 MB/s eta 0:00:01
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.8/site-packages (from jupyter-client<8,>=6.1.3->voila) (22.0.3)
# Requirement already satisfied: tornado>=4.1 in /opt/conda/lib/python3.8/site-packages (from jupyter-client<8,>=6.1.3->voila) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.8/site-packages (from jupyter-client<8,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (21.3)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.5.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.5.0)
# Collecting nbformat>=5.2.0
#   Downloading nbformat-5.4.0-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 2.4 MB/s s eta 0:00:01
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.10.1)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.9.4)
# Collecting traitlets<6,>=5.0.3
#   Downloading traitlets-5.3.0-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 72.3 MB/s eta 0:00:01
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.2.3)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (20.1.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (2.10)
# Requirement already satisfied: json5 in /opt/conda/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.25.1)
# Requirement already satisfied: babel in /opt/conda/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.9.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /opt/conda/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2->jupyter-server<2.0.0,>=1.18->voila) (2.0.1)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (1.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (49.6.0.post20210108)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (20.3.0)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.5.1)
# Requirement already satisfied: async-generator in /opt/conda/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (3.3.0)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (4.6.3)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (2.8.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (0.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (4.9.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (1.4.2)
# Collecting tinycss2
#   Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.8/site-packages (from nbconvert<7,>=6.4.5->voila) (0.1.2)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=1.18->voila) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (1.14.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (2.20)
# Requirement already satisfied: pytz>=2015.7 in /opt/conda/lib/python3.8/site-packages (from babel->jupyterlab-server<3,>=2.3.0->voila) (2021.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.8/site-packages (from beautifulsoup4->nbconvert<7,>=6.4.5->voila) (2.0.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging->jupyter-server<2.0.0,>=1.18->voila) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->jupyterlab-server<3,>=2.3.0->voila) (2021.10.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests->jupyterlab-server<3,>=2.3.0->voila) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->jupyterlab-server<3,>=2.3.0->voila) (1.26.4)
# Installing collected packages: traitlets, jupyter-core, fastjsonschema, nbformat, tinycss2, nbconvert, jupyter-server, websockets, voila
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.7.1
#     Uninstalling jupyter-core-4.7.1:
#       Successfully uninstalled jupyter-core-4.7.1
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.1.3
#     Uninstalling nbformat-5.1.3:
#       Successfully uninstalled nbformat-5.1.3
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.6.1
#     Uninstalling jupyter-server-1.6.1:
#       Successfully uninstalled jupyter-server-1.6.1
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.8/UNKNOWN
# sysconfig: /opt/conda/include/python3.8
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Successfully installed fastjsonschema-2.16.1 jupyter-core-4.11.1 jupyter-server-1.18.1 nbconvert-6.5.3 nbformat-5.4.0 tinycss2-1.1.1 traitlets-5.3.0 voila-0.3.6 websockets-10.3

# %%
import numpy as np
import pandas as pd
import folium

# %%
df = pd.read_csv('SF_crimes.csv')

# %%
import ipywidgets as widgets

style = {'description_width': 'initial'}

limit_case = widgets.IntSlider(
    value=1000,
    min=100,
    max=5000,
    step=1,
    description='Max Number of Case:',
    disabled=False,
    style=style)

# %%
unique_district = df.PdDistrict.unique()

# %%
unique_cat = df.Category.unique()

# %%
from ipywidgets import Layout

district = widgets.SelectMultiple(
    options = unique_district.tolist(),
    value = ['BAYVIEW', 'NORTHERN'],
    #rows=10,
    description='District',
    disabled=False,
    layout = Layout(width='50%', height='80px')
)

category = widgets.SelectMultiple(
    options = unique_cat.tolist(),
    value = ['VANDALISM', 'ASSAULT', 'ROBBERY'],
    #rows=10,
    description='Criminal Case',
    disabled=False,
    style=style,
    layout = Layout(width='50%', height='80px')
)

# %%
import matplotlib.pyplot as plt
from folium import plugins

def update_map(district, category, limit):
    
    df = pd.read_csv('SF_crimes.csv')
    df = df.iloc[0:limit, :]
    
    latitude = 37.77
    longitude = -122.42
    
    df_dist = df.loc[df['PdDistrict'].isin(np.array(district))]
    df_category = df_dist.loc[df_dist['Category'].isin(np.array(category))]
    
    cat_unique = df_category['Category'].value_counts()
    cat_unique = cat_unique.reset_index()
    
    dist_unique = df_category['PdDistrict'].value_counts()
    dist_unique = dist_unique.reset_index()
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))

    # create map and display it
    sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

    
    incidents = plugins.MarkerCluster().add_to(sanfran_map)

# loop through the dataframe and add each data point to the mark cluster
    for lat, lng, label, in zip(df_category.Y, df_category.X, df_category.Category):
        folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
        ).add_to(incidents)
# show map
    display(sanfran_map)
    
    ax1.bar(cat_unique['index'], cat_unique['Category'])
    ax1.set_title('Amount of Criminal Case Based on Category')
    ax2.bar(dist_unique['index'], dist_unique['PdDistrict'])
    ax2.set_title('Amount of Criminal Case in Selected District')
    
    plt.show()

# %%
widgets.interactive(update_map, district = district, category = category, limit=limit_case)
# Out:
# interactive(children=(SelectMultiple(description='District', index=(1, 4), layout=Layout(height='80px', width=…
